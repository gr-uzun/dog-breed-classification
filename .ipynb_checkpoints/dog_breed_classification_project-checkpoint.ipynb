# %% [markdown]
# <a href="https://colab.research.google.com/github/gr-uzun/dog-breed-classification/blob/main/dog_breed_classification_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **120 Dog Breed Classification**
#
# @author Gurkan UZUN
#
# @since 2023.11.21
#
# @see https://www.tensorflow.org/tutorials/images/classification
#
# @see https://towardsdatascience.com/how-to-split-a-tensorflow-dataset-into-train-validation-and-test-sets-526c8dd29438
#
# @see https://www.kaggle.com/code/balasubramaniamv/cnn-model-into-tf-lite-model
#
# @see https://www.kaggle.com/code/tamsquare/c-nn-ship-classification
#
# @see https://www.kaggle.com/code/kanncaa1/convolutional-neural-network-cnn-tutorial

# %% [markdown]
# **Dataset**
#
# https://www.kaggle.com/datasets/amandam1/120-dog-breeds-breed-classification
#
# In this project, you will be trying to create a model to classify the dog breeds using the dataset
# given above.
#
# The aim of the project is to classify the dog’s breed using the dataset which
# consists of 120 files.
#
# While creating the project, try to follow the instructions below and make
# sure that the project is unique.

# %% [markdown]
# **Attention**
#
# Before begin project, Download Kaggle Dataset directly into Google Drive (COLAB) by running **download_kaggle_dataset_into_google_drive.ipynb**

# %% [markdown]
# 2. **Importing Required Libraries**
#
# - Import the required libraries for the project to the Colab environment.
#
# - Import Pandas, NumPy, Seaborn, Matplotlib, Sklearn and Tensorflow libraries for data
# analysis.

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from keras import layers,models,datasets
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.optimizers import SGD
from keras import regularizers
# Out:
# 2023-11-29 22:36:59.147671: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 22:36:59.171107: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 22:36:59.171130: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 22:36:59.171147: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 22:36:59.175931: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# 3. **Data Preprocessing**
# - In this section, prepare the data you have, for training the model.
# - Create a dataframe that includes pixel values of images and the labels
# - Use Label Encoding or One-Hot Encoding techniques to deal with categorical targets.
# - Split your dataset into X_train,X_test, X_val, y_train, y_test and y_val
# Normalize the pixel values.

# %% [markdown]
# **Download and explore the dataset**

# %%
import pathlib

#image_folder = "/content/drive/MyDrive/Colab Notebooks/dog_breed_classification/Images/"

# project will run on local PC.
image_folder = "/home/gurkan/Downloads/dog_breed_classification/Images/"

data_dir = pathlib.Path(image_folder)
data_dir = pathlib.Path(data_dir).with_suffix('')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 20580

# %% [markdown]
# Here are some dogs:

# %%
dogs = list(data_dir.glob('n02085620-Chihuahua/*'))
PIL.Image.open(str(dogs[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7FA41F983520>

# %% [markdown]
# **Load data using a Keras utility**
#
# Next, load these images off disk using the helpful tf.keras.utils.image_dataset_from_directory utility. This will take you from a directory of images on disk to a tf.data.Dataset in just a couple lines of code. If you like, you can also write your own data loading code from scratch by visiting the Load and preprocess images tutorial.
#
# **Create a dataset**
#
# Define some parameters for the loader:

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = ds.cardinality().numpy()

    if shuffle:
        # Specify seed to always have the same split distribution between runs
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
batch_size = 32
img_height = 180
img_width = 180
channels = 3

input_shape = (img_height,img_width,channels)

batch_input_shape = (batch_size, img_height, img_width, channels)

# %%
ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=None,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 20580 files belonging to 120 classes.
# 2023-11-29 22:37:00.669891: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 22:37:00.672956: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 22:37:00.673067: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 22:37:00.673724: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 22:37:00.673804: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 22:37:00.673855: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 22:37:00.721799: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 22:37:00.721894: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 22:37:00.721951: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 22:37:00.722004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4279 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-29 22:37:00.853187: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory

# %%
# A popular split is 80%, 10% and 10% for the train, validation and test sets.

train_ds, val_ds, test_ds = get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.15, test_split=0.05, shuffle_size=image_count)

# %% [markdown]
# It's good practice to use a validation split when developing your model. Use 80% of the images for training and 20% for validation.

# %% [markdown]
# You can find the class names in the class_names attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = ds.class_names
print(class_names)

num_classes = len(class_names)
print("num_classes : ",num_classes)
# Out:
# ['n02085620-Chihuahua', 'n02085782-Japanese_spaniel', 'n02085936-Maltese_dog', 'n02086079-Pekinese', 'n02086240-Shih-Tzu', 'n02086646-Blenheim_spaniel', 'n02086910-papillon', 'n02087046-toy_terrier', 'n02087394-Rhodesian_ridgeback', 'n02088094-Afghan_hound', 'n02088238-basset', 'n02088364-beagle', 'n02088466-bloodhound', 'n02088632-bluetick', 'n02089078-black-and-tan_coonhound', 'n02089867-Walker_hound', 'n02089973-English_foxhound', 'n02090379-redbone', 'n02090622-borzoi', 'n02090721-Irish_wolfhound', 'n02091032-Italian_greyhound', 'n02091134-whippet', 'n02091244-Ibizan_hound', 'n02091467-Norwegian_elkhound', 'n02091635-otterhound', 'n02091831-Saluki', 'n02092002-Scottish_deerhound', 'n02092339-Weimaraner', 'n02093256-Staffordshire_bullterrier', 'n02093428-American_Staffordshire_terrier', 'n02093647-Bedlington_terrier', 'n02093754-Border_terrier', 'n02093859-Kerry_blue_terrier', 'n02093991-Irish_terrier', 'n02094114-Norfolk_terrier', 'n02094258-Norwich_terrier', 'n02094433-Yorkshire_terrier', 'n02095314-wire-haired_fox_terrier', 'n02095570-Lakeland_terrier', 'n02095889-Sealyham_terrier', 'n02096051-Airedale', 'n02096177-cairn', 'n02096294-Australian_terrier', 'n02096437-Dandie_Dinmont', 'n02096585-Boston_bull', 'n02097047-miniature_schnauzer', 'n02097130-giant_schnauzer', 'n02097209-standard_schnauzer', 'n02097298-Scotch_terrier', 'n02097474-Tibetan_terrier', 'n02097658-silky_terrier', 'n02098105-soft-coated_wheaten_terrier', 'n02098286-West_Highland_white_terrier', 'n02098413-Lhasa', 'n02099267-flat-coated_retriever', 'n02099429-curly-coated_retriever', 'n02099601-golden_retriever', 'n02099712-Labrador_retriever', 'n02099849-Chesapeake_Bay_retriever', 'n02100236-German_short-haired_pointer', 'n02100583-vizsla', 'n02100735-English_setter', 'n02100877-Irish_setter', 'n02101006-Gordon_setter', 'n02101388-Brittany_spaniel', 'n02101556-clumber', 'n02102040-English_springer', 'n02102177-Welsh_springer_spaniel', 'n02102318-cocker_spaniel', 'n02102480-Sussex_spaniel', 'n02102973-Irish_water_spaniel', 'n02104029-kuvasz', 'n02104365-schipperke', 'n02105056-groenendael', 'n02105162-malinois', 'n02105251-briard', 'n02105412-kelpie', 'n02105505-komondor', 'n02105641-Old_English_sheepdog', 'n02105855-Shetland_sheepdog', 'n02106030-collie', 'n02106166-Border_collie', 'n02106382-Bouvier_des_Flandres', 'n02106550-Rottweiler', 'n02106662-German_shepherd', 'n02107142-Doberman', 'n02107312-miniature_pinscher', 'n02107574-Greater_Swiss_Mountain_dog', 'n02107683-Bernese_mountain_dog', 'n02107908-Appenzeller', 'n02108000-EntleBucher', 'n02108089-boxer', 'n02108422-bull_mastiff', 'n02108551-Tibetan_mastiff', 'n02108915-French_bulldog', 'n02109047-Great_Dane', 'n02109525-Saint_Bernard', 'n02109961-Eskimo_dog', 'n02110063-malamute', 'n02110185-Siberian_husky', 'n02110627-affenpinscher', 'n02110806-basenji', 'n02110958-pug', 'n02111129-Leonberg', 'n02111277-Newfoundland', 'n02111500-Great_Pyrenees', 'n02111889-Samoyed', 'n02112018-Pomeranian', 'n02112137-chow', 'n02112350-keeshond', 'n02112706-Brabancon_griffon', 'n02113023-Pembroke', 'n02113186-Cardigan', 'n02113624-toy_poodle', 'n02113712-miniature_poodle', 'n02113799-standard_poodle', 'n02113978-Mexican_hairless', 'n02115641-dingo', 'n02115913-dhole', 'n02116738-African_hunting_dog']
# num_classes :  120

# %% [markdown]
# **Visualize the data**
#
# Here are the first nine images from the training dataset:

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# You will pass these datasets to the Keras Model.fit method for training later in this tutorial. If you like, you can also manually iterate over the dataset and retrieve batches of images:

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# The image_batch is a tensor of the shape (32, 180, 180, 3). This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.
#
# You can call .numpy() on the image_batch and labels_batch tensors to convert them to a numpy.ndarray.

# %% [markdown]
# **Configure the dataset for performance**
#
# Make sure to use buffered prefetching, so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data:
#
# - Dataset.cache keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
#
# - Dataset.prefetch overlaps data preprocessing and model execution while training.
#
# Interested readers can learn more about both methods, as well as how to cache data to disk in the Prefetching section of the Better performance with the tf.data API guide.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# **Standardize the data**
#
# The RGB channel values are in the [0, 255] range. This is not ideal for a neural network; in general you should seek to make your input values small.
#
# Here, you will standardize values to be in the [0, 1] range by using tf.keras.layers.Rescaling:

# %%
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# There are two ways to use this layer. You can apply it to the dataset by calling Dataset.map:

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# Or, you can include the layer inside your model definition, which can simplify deployment. Use the second approach here.

# %% [markdown]
# **Note**: You previously resized images using the image_size argument of tf.keras.utils.image_dataset_from_directory. If you want to include the resizing logic in your model as well, you can use the tf.keras.layers.Resizing layer.

# %% [markdown]
# **Overfitting**
#
# In the plots above, the training accuracy is increasing linearly over time, whereas validation accuracy stalls around 60% in the training process. Also, the difference in accuracy between training and validation accuracy is noticeable—a sign of overfitting.
#
# When there are a small number of training examples, the model sometimes learns from noises or unwanted details from training examples—to an extent that it negatively impacts the performance of the model on new examples. This phenomenon is known as overfitting. It means that the model will have a difficult time generalizing on a new dataset.
#
# There are multiple ways to fight overfitting in the training process. In this tutorial, you'll use data augmentation and add dropout to your model.

# %% [markdown]
# **Data augmentation**
#
# Overfitting generally occurs when there are a small number of training examples. Data augmentation takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.
#
# You will implement data augmentation using the following Keras preprocessing layers: tf.keras.layers.RandomFlip, tf.keras.layers.RandomRotation, and tf.keras.layers.RandomZoom. These can be included inside your model like other layers, and run on the GPU.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape = input_shape),
    layers.RandomRotation(0.1)
    #layers.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Visualize a few augmented examples by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# You will add data augmentation to your model before training in the next step.

# %% [markdown]
# **Dropout**
#
# Another technique to reduce overfitting is to introduce dropout regularization to the network.
#
# When you apply dropout to a layer, it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.
#
# Create a new neural network with tf.keras.layers.Dropout before training it using the augmented images:

# %% [markdown]
# 4. **Building a Model**
#
# - Build a model using Tensorflow or Pytorch
# - Your model should include Conv2D, MaxPooling2D, Flatten, Dense and
# Dropout.(Number of layers is up to you)
# - Compile your model and print the summary of the model.
# - Train your model using train and validation subsets
# - Plot model’s accuracy, validation accuracy, loss and validation loss.
#
# **Hint**: Use “Softmax” as the activation function of the last Dense Layer.

# %% [markdown]
# **Create the model**
#
# The Keras Sequential model consists of three convolution blocks (tf.keras.layers.Conv2D) with a max pooling layer (tf.keras.layers.MaxPooling2D) in each of them. There's a fully-connected layer (tf.keras.layers.Dense) with 128 units on top of it that is activated by a ReLU activation function ('relu'). This model has not been tuned for high accuracy; the goal of this tutorial is to show a standard approach.

# %%
model = Sequential([

  data_augmentation,

  layers.Rescaling(1./255),

  layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same',
                input_shape=input_shape), 
                # kernel_regularizer = regularizers.L2(0.001)),
  layers.MaxPooling2D((2, 2)),
  #layers.Dropout(0.1),

  layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
  layers.MaxPooling2D((2, 2)),
  #layers.Dropout(0.1),

  layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
  layers.MaxPooling2D((2, 2)),
  layers.Dropout(0.5),

  layers.Flatten(),

  layers.Dense(128, activation='relu', kernel_initializer='he_uniform'),

  layers.Dense(num_classes, activation='softmax')
])

model.build(input_shape = batch_input_shape)

# %% [markdown]
# **Train the model with the ModelCheckpoint callback and keep history**

# %%
# cancelled
#checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# %% [markdown]
# **Compile the model**
#
# For this tutorial, choose the tf.keras.optimizers.Adam optimizer and tf.keras.losses.SparseCategoricalCrossentropy loss function. To view training and validation accuracy for each training epoch, pass the metrics argument to Model.compile.

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

#model.compile(optimizer='sgd',loss='categorical_crossentropy', metrics=['acc', 'mse'])

# %% [markdown]
# **Model summary**
#
# View all the layers of the network using the Keras Model.summary method:

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 128)       0
#  g2D)
#
#  dropout (Dropout)           (None, 22, 22, 128)       0
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 128)               7929984
#
#  dense_1 (Dense)             (None, 120)               15480
#
# =================================================================
# Total params: 8038712 (30.67 MB)
# Trainable params: 8038712 (30.67 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Train the model**
#
# Train the model for xxx epochs with the Keras Model.fit method:

# %%
epochs = 100

# Early Stopping
# Instead of training for a fixed number of epochs, you stop as soon as the validation loss rises
#early_stopping_callback = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)

# Train the model
history = model.fit(
    train_ds,
    batch_size=batch_size,
    validation_data=val_ds,
    verbose=1,
    epochs=epochs,
    use_multiprocessing=True
   #callbacks=[early_stopping_callback]
   #callbacks=[checkpoint] cancelled
)
# Out:
# Epoch 1/100
# 2023-11-29 22:37:11.851422: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-29 22:37:11.943784: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2023-11-29 22:37:12.010141: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-11-29 22:37:12.500790: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa1fc123ed0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-29 22:37:12.500806: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2023-11-29 22:37:12.504196: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-29 22:37:12.548830: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 515/515 [==============================] - 22s 39ms/step - loss: 4.8050 - accuracy: 0.0183 - val_loss: 4.5291 - val_accuracy: 0.0309
# Epoch 2/100
# 515/515 [==============================] - 17s 32ms/step - loss: 4.4405 - accuracy: 0.0385 - val_loss: 4.2355 - val_accuracy: 0.0553
# Epoch 3/100
# 515/515 [==============================] - 17s 32ms/step - loss: 4.2521 - accuracy: 0.0596 - val_loss: 4.1048 - val_accuracy: 0.0785
# Epoch 4/100
# 515/515 [==============================] - 17s 32ms/step - loss: 4.1196 - accuracy: 0.0729 - val_loss: 3.9875 - val_accuracy: 0.0990
# Epoch 5/100
# 515/515 [==============================] - 17s 32ms/step - loss: 3.9893 - accuracy: 0.0930 - val_loss: 3.9075 - val_accuracy: 0.1182
# Epoch 6/100
# 515/515 [==============================] - 17s 32ms/step - loss: 3.8732 - accuracy: 0.1114 - val_loss: 3.7791 - val_accuracy: 0.1325
# Epoch 7/100
# 515/515 [==============================] - 17s 32ms/step - loss: 3.7684 - accuracy: 0.1293 - val_loss: 3.6069 - val_accuracy: 0.1680
# Epoch 8/100
# 515/515 [==============================] - 17s 32ms/step - loss: 3.6673 - accuracy: 0.1464 - val_loss: 3.4611 - val_accuracy: 0.1826
# Epoch 9/100
# 515/515 [==============================] - 17s 32ms/step - loss: 3.5558 - accuracy: 0.1629 - val_loss: 3.4290 - val_accuracy: 0.1943
# Epoch 10/100
# 515/515 [==============================] - 17s 32ms/step - loss: 3.4867 - accuracy: 0.1733 - val_loss: 3.3045 - val_accuracy: 0.2158
# Epoch 11/100
# 515/515 [==============================] - 17s 32ms/step - loss: 3.3928 - accuracy: 0.1918 - val_loss: 3.2797 - val_accuracy: 0.2256
# Epoch 12/100
# 515/515 [==============================] - 17s 33ms/step - loss: 3.3224 - accuracy: 0.2034 - val_loss: 3.1474 - val_accuracy: 0.2419
# Epoch 13/100
# 515/515 [==============================] - 17s 33ms/step - loss: 3.2434 - accuracy: 0.2183 - val_loss: 3.0503 - val_accuracy: 0.2620
# Epoch 14/100
# 515/515 [==============================] - 17s 33ms/step - loss: 3.1747 - accuracy: 0.2311 - val_loss: 3.1113 - val_accuracy: 0.2549
# Epoch 15/100
# 515/515 [==============================] - 17s 33ms/step - loss: 3.0926 - accuracy: 0.2471 - val_loss: 3.0610 - val_accuracy: 0.2604
# Epoch 16/100
# 515/515 [==============================] - 17s 33ms/step - loss: 3.0523 - accuracy: 0.2577 - val_loss: 3.0172 - val_accuracy: 0.2751
# Epoch 17/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.9875 - accuracy: 0.2719 - val_loss: 2.8511 - val_accuracy: 0.3079
# Epoch 18/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.9330 - accuracy: 0.2811 - val_loss: 2.8785 - val_accuracy: 0.3018
# Epoch 19/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.8820 - accuracy: 0.2910 - val_loss: 2.7717 - val_accuracy: 0.3210
# Epoch 20/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.8279 - accuracy: 0.3003 - val_loss: 2.9060 - val_accuracy: 0.3005
# Epoch 21/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.7614 - accuracy: 0.3140 - val_loss: 2.6946 - val_accuracy: 0.3398
# Epoch 22/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.7308 - accuracy: 0.3175 - val_loss: 2.8126 - val_accuracy: 0.3206
# Epoch 23/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.6891 - accuracy: 0.3313 - val_loss: 2.5957 - val_accuracy: 0.3610
# Epoch 24/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.6484 - accuracy: 0.3339 - val_loss: 2.5967 - val_accuracy: 0.3773
# Epoch 25/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.5964 - accuracy: 0.3406 - val_loss: 2.5821 - val_accuracy: 0.3695
# Epoch 26/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.5647 - accuracy: 0.3572 - val_loss: 2.4883 - val_accuracy: 0.3997
# Epoch 27/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.4955 - accuracy: 0.3710 - val_loss: 2.5707 - val_accuracy: 0.3864
# Epoch 28/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.4583 - accuracy: 0.3754 - val_loss: 2.4427 - val_accuracy: 0.4105
# Epoch 29/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.4248 - accuracy: 0.3872 - val_loss: 2.4477 - val_accuracy: 0.4010
# Epoch 30/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.3882 - accuracy: 0.3872 - val_loss: 2.3810 - val_accuracy: 0.4248
# Epoch 31/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.3796 - accuracy: 0.3964 - val_loss: 2.5798 - val_accuracy: 0.3743
# Epoch 32/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.3278 - accuracy: 0.4033 - val_loss: 2.3648 - val_accuracy: 0.4404
# Epoch 33/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.2815 - accuracy: 0.4143 - val_loss: 2.4775 - val_accuracy: 0.4092
# Epoch 34/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.2690 - accuracy: 0.4113 - val_loss: 2.4231 - val_accuracy: 0.4219
# Epoch 35/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.2344 - accuracy: 0.4232 - val_loss: 2.2480 - val_accuracy: 0.4570
# Epoch 36/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.1883 - accuracy: 0.4384 - val_loss: 2.2015 - val_accuracy: 0.4642
# Epoch 37/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.1662 - accuracy: 0.4362 - val_loss: 2.4142 - val_accuracy: 0.4222
# Epoch 38/100
# 515/515 [==============================] - 17s 34ms/step - loss: 2.1344 - accuracy: 0.4493 - val_loss: 2.1854 - val_accuracy: 0.4749
# Epoch 39/100
# 515/515 [==============================] - 17s 34ms/step - loss: 2.1101 - accuracy: 0.4511 - val_loss: 2.2207 - val_accuracy: 0.4645
# Epoch 40/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.0959 - accuracy: 0.4515 - val_loss: 2.3659 - val_accuracy: 0.4336
# Epoch 41/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.0684 - accuracy: 0.4613 - val_loss: 2.3137 - val_accuracy: 0.4453
# Epoch 42/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.0307 - accuracy: 0.4647 - val_loss: 2.2698 - val_accuracy: 0.4564
# Epoch 43/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.0099 - accuracy: 0.4759 - val_loss: 2.1986 - val_accuracy: 0.4792
# Epoch 44/100
# 515/515 [==============================] - 17s 33ms/step - loss: 2.0012 - accuracy: 0.4743 - val_loss: 2.2344 - val_accuracy: 0.4674
# Epoch 45/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.9664 - accuracy: 0.4826 - val_loss: 2.0431 - val_accuracy: 0.5137
# Epoch 46/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.9391 - accuracy: 0.4879 - val_loss: 2.1761 - val_accuracy: 0.4958
# Epoch 47/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.9385 - accuracy: 0.4906 - val_loss: 2.0548 - val_accuracy: 0.5111
# Epoch 48/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.9015 - accuracy: 0.4963 - val_loss: 2.2082 - val_accuracy: 0.4753
# Epoch 49/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.8753 - accuracy: 0.5040 - val_loss: 2.1149 - val_accuracy: 0.5091
# Epoch 50/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.8534 - accuracy: 0.5110 - val_loss: 2.0072 - val_accuracy: 0.5361
# Epoch 51/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.8509 - accuracy: 0.5079 - val_loss: 2.1917 - val_accuracy: 0.4954
# Epoch 52/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.8326 - accuracy: 0.5136 - val_loss: 2.1628 - val_accuracy: 0.5007
# Epoch 53/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.8023 - accuracy: 0.5225 - val_loss: 2.0192 - val_accuracy: 0.5309
# Epoch 54/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.7784 - accuracy: 0.5262 - val_loss: 2.0384 - val_accuracy: 0.5352
# Epoch 55/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.7759 - accuracy: 0.5263 - val_loss: 2.0203 - val_accuracy: 0.5316
# Epoch 56/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.7658 - accuracy: 0.5268 - val_loss: 1.9119 - val_accuracy: 0.5641
# Epoch 57/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.7397 - accuracy: 0.5369 - val_loss: 1.9409 - val_accuracy: 0.5654
# Epoch 58/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.7277 - accuracy: 0.5387 - val_loss: 1.9787 - val_accuracy: 0.5570
# Epoch 59/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.7040 - accuracy: 0.5433 - val_loss: 1.8980 - val_accuracy: 0.5713
# Epoch 60/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.6650 - accuracy: 0.5512 - val_loss: 1.9838 - val_accuracy: 0.5527
# Epoch 61/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.6729 - accuracy: 0.5460 - val_loss: 2.1056 - val_accuracy: 0.5303
# Epoch 62/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.6675 - accuracy: 0.5517 - val_loss: 1.9953 - val_accuracy: 0.5365
# Epoch 63/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.6237 - accuracy: 0.5639 - val_loss: 1.9304 - val_accuracy: 0.5648
# Epoch 64/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.6280 - accuracy: 0.5593 - val_loss: 2.1501 - val_accuracy: 0.5202
# Epoch 65/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.6111 - accuracy: 0.5622 - val_loss: 2.0712 - val_accuracy: 0.5306
# Epoch 66/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.5977 - accuracy: 0.5698 - val_loss: 1.8470 - val_accuracy: 0.5879
# Epoch 67/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.5919 - accuracy: 0.5716 - val_loss: 1.9870 - val_accuracy: 0.5553
# Epoch 68/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.5688 - accuracy: 0.5752 - val_loss: 1.8423 - val_accuracy: 0.5859
# Epoch 69/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.5669 - accuracy: 0.5805 - val_loss: 1.8064 - val_accuracy: 0.6084
# Epoch 70/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.5407 - accuracy: 0.5830 - val_loss: 1.9101 - val_accuracy: 0.5798
# Epoch 71/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.5232 - accuracy: 0.5855 - val_loss: 1.9585 - val_accuracy: 0.5710
# Epoch 72/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.5284 - accuracy: 0.5908 - val_loss: 1.9396 - val_accuracy: 0.5739
# Epoch 73/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.5123 - accuracy: 0.5856 - val_loss: 2.0809 - val_accuracy: 0.5479
# Epoch 74/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.4974 - accuracy: 0.5948 - val_loss: 1.8610 - val_accuracy: 0.5908
# Epoch 75/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.4839 - accuracy: 0.5925 - val_loss: 2.0262 - val_accuracy: 0.5550
# Epoch 76/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.4635 - accuracy: 0.5997 - val_loss: 1.9428 - val_accuracy: 0.5742
# Epoch 77/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.4640 - accuracy: 0.6004 - val_loss: 1.7935 - val_accuracy: 0.6038
# Epoch 78/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.4403 - accuracy: 0.6036 - val_loss: 2.0531 - val_accuracy: 0.5492
# Epoch 79/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.4335 - accuracy: 0.6024 - val_loss: 1.9498 - val_accuracy: 0.5729
# Epoch 80/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.4181 - accuracy: 0.6078 - val_loss: 1.9932 - val_accuracy: 0.5693
# Epoch 81/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3834 - accuracy: 0.6168 - val_loss: 1.7967 - val_accuracy: 0.6185
# Epoch 82/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.4320 - accuracy: 0.6073 - val_loss: 1.8298 - val_accuracy: 0.6156
# Epoch 83/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3913 - accuracy: 0.6173 - val_loss: 1.9707 - val_accuracy: 0.5824
# Epoch 84/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3970 - accuracy: 0.6163 - val_loss: 1.7502 - val_accuracy: 0.6312
# Epoch 85/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3742 - accuracy: 0.6196 - val_loss: 1.9984 - val_accuracy: 0.5729
# Epoch 86/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3439 - accuracy: 0.6278 - val_loss: 1.7332 - val_accuracy: 0.6416
# Epoch 87/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3487 - accuracy: 0.6309 - val_loss: 1.8612 - val_accuracy: 0.6130
# Epoch 88/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3367 - accuracy: 0.6276 - val_loss: 1.7907 - val_accuracy: 0.6182
# Epoch 89/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3253 - accuracy: 0.6334 - val_loss: 1.6748 - val_accuracy: 0.6514
# Epoch 90/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3363 - accuracy: 0.6255 - val_loss: 1.8575 - val_accuracy: 0.6159
# Epoch 91/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3310 - accuracy: 0.6288 - val_loss: 1.9446 - val_accuracy: 0.5876
# Epoch 92/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.3093 - accuracy: 0.6422 - val_loss: 1.9175 - val_accuracy: 0.5980
# Epoch 93/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.2896 - accuracy: 0.6434 - val_loss: 1.8627 - val_accuracy: 0.6185
# Epoch 94/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.2791 - accuracy: 0.6445 - val_loss: 2.0974 - val_accuracy: 0.5651
# Epoch 95/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.2959 - accuracy: 0.6389 - val_loss: 2.0007 - val_accuracy: 0.5928
# Epoch 96/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.2661 - accuracy: 0.6444 - val_loss: 1.8807 - val_accuracy: 0.6208
# Epoch 97/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.2627 - accuracy: 0.6492 - val_loss: 1.6831 - val_accuracy: 0.6624
# Epoch 98/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.2761 - accuracy: 0.6500 - val_loss: 1.9612 - val_accuracy: 0.6009
# Epoch 99/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.2603 - accuracy: 0.6475 - val_loss: 1.8734 - val_accuracy: 0.6143
# Epoch 100/100
# 515/515 [==============================] - 17s 33ms/step - loss: 1.2380 - accuracy: 0.6503 - val_loss: 1.9104 - val_accuracy: 0.6182

# %%
# cancelled
# save model
# model.save('my_model.keras')

# %% [markdown]
# **Visualize training results**
#
# After applying data augmentation and tf.keras.layers.Dropout, there is less overfitting than before, and training and validation accuracy are closer aligned:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Testing the CNN model**
#
# Use your model to classify an image that wasn't included in the training or validation sets.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(test_ds)
print(f"Test Accuracy: {round(scores[1],4)*100}%")
# Out:
# [INFO] Calculating model accuracy
# 33/33 [==============================] - 6s 12ms/step - loss: 2.0212 - accuracy: 0.5914
# Test Accuracy: 59.14%

# %%
def predict(model, img):

    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    
    img_array = img_array.reshape(input_shape)
    
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(25, 25))

plt.suptitle('First 15 Predicted Images with Predicted Classes', size=25)

for images, labels in test_ds.take(1):
    for i in range(15):
        ax = plt.subplot(5, 3, i + 1)

        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        
        actual_class = class_names[labels[i]] 

        if actual_class == predicted_class:
          title_color = 'green'
        else:
          title_color = 'red'

        title = f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%"

        plt.title(title, color=title_color)

        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
